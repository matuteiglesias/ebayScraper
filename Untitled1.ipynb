# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('ScrapedData2.csv')

# %%
print len(df)
df.sort_values(by = 'sales', ascending=False).drop_duplicates(subset = 'title',keep = False).head(20)
# Out:
# 1300
#                                                                                                       title  \
# 637   FEELWORLD 7 Inch TFT LCD HD 1080P HDMI DSLR Camera Video Monitor  | eBay
# 755   688C Professional Portable Carbon Fiber Tripod Monopod&Ball Head for DSLR camera  | eBay
# 1137  SPECIAL LUIGI&apos;s DELUXE STRAP WITH 2 LENGHT ADJUSTMENTS,BLACK,OR MAKE YOUR CHOICE  | eBay
# 806   TurnsPro - 360° Timelapse Panning device for GoPro HERO | DSLR | Smart Phones  | eBay
# 849   300 LED Ring Lighting Light Video Film Continuous Light + Camera Bracket/ filter  | eBay
# 289   Nikon Normal AF Nikkor 50mm f/1.8D Autofocus Lens w/52mm UV Filter 18208021376 | eBay
# 892   Underwater Waterproof Housing Case Cover Bag for Canon Powershot S110  | eBay
# 936   Gitup Git2 Sports Action Camera DVR 1080P 16MP 2K Wifi+Battery+FPV+Dual Charger  | eBay
# 617   FOTGA DP3000 15mm Rod Baseplate+Shoulder Pad+Handle Grip Support Rail System Rig  | eBay
# ...

# %%
plt.hist(df.sales, 200)
plt.xlim(0, 10)
plt.show()
